# %% [markdown]
# <a href="https://colab.research.google.com/github/SriAmruthaVantrapati/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-07 13:33:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   134MB/s    in 0.5s
#
# 2023-05-07 13:33:27 (134 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3760 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 16  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22850  1709.00843v1  The small-ball method was introduced as a way ...  stat
# 21759   1205.3234v5  Hierarchical parametric models consisting of o...  stat
# 21222  1710.07075v1  We use decision trees to build a helpdesk agen...    cs
# 18533   1105.5442v1  It is common to view programs as a combination...    cs
# 9687   1703.01506v2  Permutation testing is a non-parametric method...  stat
# ...             ...                                                ...   ...
# 24468   1404.0533v1  Szeliski et al. published an influential study...    cs
# 7158   1710.09567v1  We present an algorithm for classification tas...  stat
# 37332  1704.00264v1  Rapidly-exploring Random Tree Star(RRT*) is a ...    cs
# 24834   1412.1908v1  Human eyes can recognize person identities bas...    cs
# 10053  1701.03162v1  In this paper, we try to predict the winning t...  stat
#
#                                                    title  year  \
# 22850                    Extending the small-ball method  2017
# 21759  Asymptotic Accuracy of Bayes Estimation for La...  2012
# 21222         Decision Trees for Helpdesk Advisor Graphs  2017
# 18533  The Divide-and-Conquer Subgoal-Ordering Algori...  2011
# 9687   Accelerating Permutation Testing in Voxel-wise...  2017
# ...                                                  ...   ...
# 24468  A Comparative Study of Modern Inference Techni...  2014
# 7158   Big Data Classification Using Augmented Decisi...  2017
# 37332  Potential Functions based Sampling Heuristic F...  2017
# 24834      Person Re-identification by Saliency Learning  2014
# 10053          Real-time eSports Match Result Prediction  2016
#
#                   keywords
# 22850                   []
# 21759                   []
# 21222  [telecommunication]
# 18533                   []
# 9687                    []
# ...                    ...
# 24468                   []
# 7158                    []
# 37332                   []
# 24834                   []
# 10053                   []
#
# [5008 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22850                     []
# 21759                     []
# 21222    [telecommunication]
# 18533                     []
# 9687                      []
#                 ...
# 22790                     []
# 20810                     []
# 19539                     []
# 21702                     []
# 10623                     []
# Name: keywords, Length: 6260, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 334 words.
# Out of those 38 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="39c4264e-7f5f-45ea-a675-fed5f6411182" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39c4264e-7f5f-45ea-a675-fed5f6411182")) {                    Plotly.newPlot(                        "39c4264e-7f5f-45ea-a675-fed5f6411182",                        [{"x":["telecommunication","multilayerperception","heteroscedasticity","deterministically","acceptancerejection","reparameterization","explodingvanishing","neurophysiological","differentiability","interrelationship","eigendecomposition","characterizations","electroencephalogram","misclassification","reparametrization","interdisciplinary","characterisations","contextualization","spectroradiometer","probabilistically","neuropsychological","nonparametrically","interdependencies","conceptualization","misclassifications","indistinguishable","conceptualizations","featurescomponents","parameterizations","parallelizability","straightforwardly","electroencephalography","interchangeability","regressionclassification","neurodegenerative","telecommunications","electrophysiology","detectionrecognition"],"y":[2,2,1,4,0,1,0,2,2,1,2,5,2,12,1,1,2,1,0,5,2,1,3,3,1,6,3,2,1,1,0,0,2,0,1,2,1,2],"type":"bar"},{"x":["telecommunication","multilayerperception","heteroscedasticity","deterministically","acceptancerejection","reparameterization","explodingvanishing","neurophysiological","differentiability","interrelationship","eigendecomposition","characterizations","electroencephalogram","misclassification","reparametrization","interdisciplinary","characterisations","contextualization","spectroradiometer","probabilistically","neuropsychological","nonparametrically","interdependencies","conceptualization","misclassifications","indistinguishable","conceptualizations","featurescomponents","parameterizations","parallelizability","straightforwardly","electroencephalography","interchangeability","regressionclassification","neurodegenerative","telecommunications","electrophysiology","detectionrecognition"],"y":[0,0,1,2,2,8,2,0,3,1,3,3,2,12,3,2,0,1,2,2,0,1,1,0,2,2,0,0,2,1,2,2,0,2,1,0,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"cont ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (38,), (38, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.3777955271565495

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Parameterised</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>Hierarchy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Argumentation</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>Semantics</span> <span style=''>for</span> <span style=''>Extended</span> <span style=''>Logic</span> <span style='background-color:rgba(0, 255, 0, 0.4715025906735752);'>Programming</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Well</span> <span style=''>founded</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>Semantics</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Argumentation</span> <span style=''>has</span> <span style=''>proved</span> <span style=''>a</span> <span style=''>useful</span> <span style=''>tool</span> <span style=''>in</span> <span style=''>defining</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.7702702702702703);'>reasoning</span> <span style=''>by</span> <span style=''>viewing</span> <span style=''>a</span> <span style=''>proof</span> <span style=''>as</span> <span style=''>a</span> <span style=''>process</span> <span style=''>in</span> <span style=''>which</span> <span style=''>proponents</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>opponents</span> <span style=''>attack</span> <span style=''>each</span> <span style=''>others</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>by</span> <span style=''>undercuts</span> <span style=''>(attack</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>premise)</span> <span style=''>and</span> <span style=''>rebuts</span> <span style=''>(attack</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>conclusion)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>attack</span> <span style=''>for</span> <span style=''>extended</span> <span style=''>logic</span> <span style=''>programs</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3220338983050847);'>combinations</span> <span style=''>of</span> <span style=''>undercuts</span> <span style=''>and</span> <span style=''>rebuts</span> <span style=''>and</span> <span style=''>define</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>hierarchy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>argumentation</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>parameterised</span> <span style=''>by</span> <span style=''>the</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>attack</span> <span style=''>chosen</span> <span style=''>by</span> <span style=''>proponent</span> <span style=''>and</span> <span style=''>opponent</span> <span style=''>We</span> <span style=''>prove</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Iterative</span> <span style=''>Machine</span> <span style=''>Teaching</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>teaching</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Different</span> <span style=''>from</span> <span style=''>traditional</span> <span style=''>machine</span> <span style=''>teaching</span> <span style=''>which</span> <span style=''>views</span> <span style=''>the</span> <span style=''>learners</span> <span style=''>as</span> <span style=''>batch</span> <span style=''>algorithms</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style=''>new</span> <span style=''>paradigm</span> <span style=''>where</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>uses</span> <span style=''>an</span> <span style=''>iterative</span> <span style=''>algorithm</span> <span style=''>and</span> <span style=''>a</span> <span style=''>teacher</span> <span style=''>can</span> <span style=''>feed</span> <span style=''>examples</span> <span style=''>sequentially</span> <span style=''>and</span> <span style=''>intelligently</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>current</span> <span style=''>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>teaching</span> <span style=''>complexity</span> <span style=''>in</span> <span style=''>the</span> <span style=''>iterative</span> <span style=''>case</span> <span style=''>is</span> <span style=''>very</span> <span style=''>different</span> <span style=''>from</span> <span style=''>that</span> <span style=''>in</span> <span style=''>the</span> <span style=''>batch</span> <span style=''>case</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>constructing</span> <span style=''>a</span> <span style=''>minimal</span> <span style=''>training</span> <span style=''>set</span> <span style=''>for</span> <span style=''>learners</span> <span style=''>our</span> <span style=''>iterative</span> <span style=''>machine</span> <span style=''>teaching</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>achieving</span> <span style=''>fast</span> <span style=''>convergence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>model</span> <span style=''>Depending</span> <span style=''>on</span> <span style=''>the</span> <span style=''>level</span> <span style=''>of</span> <span style=''>information</span> <span style=''>the</span> <span style=''>teacher</span> <span style=''>has</span> <span style=''>from</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>model</span> <span style=''>we</span> <span style=''>design</span> <span style=''>teaching</span> <span style=''>algorithms</span> <span style=''>which</span> <span style=''>can</span> <span style=''>provably</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>teaching</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>faster</span> <span style=''>convergence</span> <span style=''>than</span> <span style=''>learning</span> <span style=''>without</span> <span style=''>teachers</span> <span style=''>We</span> <span style=''>also</span> <span style=''>validate</span> <span style=''>our</span> <span style=''>theoretical</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Subjective</span> <span style=''>and</span> <span style=''>Objective</span> <span style=''>Evaluation</span> <span style=''>of</span> <span style=''>English</span> <span style=''>to</span> <span style=''>Urdu</span> <span style=''>Machine</span> <span style=''>Translation</span> <br/><br/><span style=''>Machine</span> <span style=''>translation</span> <span style=''>is</span> <span style=''>research</span> <span style=''>based</span> <span style=''>area</span> <span style=''>where</span> <span style=''>evaluation</span> <span style=''>is</span> <span style=''>very</span> <span style=''>important</span> <span style=''>phenomenon</span> <span style=''>for</span> <span style=''>checking</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>MT</span> <span style=''>output</span> <span style=''>The</span> <span style=''>work</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>evaluation</span> <span style=''>of</span> <span style=''>English</span> <span style=''>to</span> <span style=''>Urdu</span> <span style=''>Machine</span> <span style=''>translation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>research</span> <span style=''>work</span> <span style=''>we</span> <span style=''>have</span> <span style=''>evaluated</span> <span style=''>the</span> <span style=''>translation</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>Urdu</span> <span style=''>language</span> <span style=''>which</span> <span style=''>has</span> <span style=''>been</span> <span style=''>translated</span> <span style=''>by</span> <span style=''>using</span> <span style=''>different</span> <span style=''>Machine</span> <span style=''>Translation</span> <span style=''>systems</span> <span style=''>like</span> <span style=''>Google</span> <span style=''>Babylon</span> <span style=''>and</span> <span style=''>Ijunoon</span> <span style=''>The</span> <span style=''>evaluation</span> <span style=''>process</span> <span style=''>is</span> <span style=''>done</span> <span style=''>by</span> <span style=''>using</span> <span style=''>two</span> <span style=''>approaches</span> <span style=''>Human</span> <span style=''>evaluation</span> <span style=''>and</span> <span style=''>Automatic</span> <span style=''>evaluation</span> <span style=''>We</span> <span style=''>have</span> <span style=''>worked</span> <span style=''>for</span> <span style=''>both</span> <span style=''>the</span> <span style=''>approaches</span> <span style=''>where</span> <span style=''>in</span> <span style=''>human</span> <span style=''>evaluation</span> <span style=''>emphasis</span> <span style=''>is</span> <span style=''>given</span> <span style=''>to</span> <span style=''>scales</span> <span style=''>and</span> <span style=''>parameters</span> <span style=''>while</span> <span style=''>in</span> <span style=''>automatic</span> <span style=''>evaluation</span> <span style=''>emphasis</span> <span style=''>is</span> <span style=''>given</span> <span style=''>to</span> <span style=''>some</span> <span style=''>automatic</span> <span style=''>metric</span> <span style=''>such</span> <span style=''>as</span> <span style=''>BLEU</span> <span style=''>GTM</span> <span style=''>METEOR</span> <span style=''>and</span> <span style=''>ATEC</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	neuropsychological (0.0006738544474393531)
# 	characterisations (0.0006738544474393531)
# 	neurophysiological (0.0006738544474393531)
# 	multilayerperception (0.0006738544474393531)
# 	featurescomponents (0.0006738544474393531)
# 	detectionrecognition (0.0006738544474393531)
# 	probabilistically (0.0016846361185983828)
# 	conceptualizations (0.0010107816711590297)
# 	conceptualization (0.0010107816711590297)
# 	indistinguishable (0.0020215633423180594)
#
# Some Statistics words are:
# 	differentiability (0.0014705882352941176)
# 	acceptancerejection (0.000980392156862745)
# 	explodingvanishing (0.000980392156862745)
# 	straightforwardly (0.000980392156862745)
# 	electroencephalography (0.000980392156862745)
# 	regressionclassification (0.000980392156862745)
# 	spectroradiometer (0.000980392156862745)
# 	reparametrization (0.0014705882352941176)
# 	misclassification (0.0058823529411764705)
# 	reparameterization (0.00392156862745098)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c2bebfda-4f6e-4a93-9ce0-e94f4cb84177" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2bebfda-4f6e-4a93-9ce0-e94f4cb84177")) {                    Plotly.newPlot(                        "c2bebfda-4f6e-4a93-9ce0-e94f4cb84177",                        [{"x":["telecommunication","multilayerperception","heteroscedasticity","deterministically","acceptancerejection","reparameterization","explodingvanishing","neurophysiological","differentiability","interrelationship","eigendecomposition","characterizations","electroencephalogram","misclassification","reparametrization","interdisciplinary","characterisations","contextualization","spectroradiometer","probabilistically","neuropsychological","nonparametrically","interdependencies","conceptualization","misclassifications","indistinguishable","conceptualizations","featurescomponents","parameterizations","parallelizability","straightforwardly","electroencephalography","interchangeability","regressionclassification","neurodegenerative","telecommunications","electrophysiology","detectionrecognition"],"y":[0.0006738544474393531,0.0006738544474393531,0.00033692722371967657,0.0013477088948787063,0.0,0.00033692722371967657,0.0,0.0006738544474393531,0.0006738544474393531,0.00033692722371967657,0.0006738544474393531,0.0016846361185983828,0.0006738544474393531,0.004043126684636119,0.00033692722371967657,0.00033692722371967657,0.0006738544474393531,0.00033692722371967657,0.0,0.0016846361185983828],"type":"bar"},{"x":["telecommunication","multilayerperception","heteroscedasticity","deterministically","acceptancerejection","reparameterization","explodingvanishing","neurophysiological","differentiability","interrelationship","eigendecomposition","characterizations","electroencephalogram","misclassification","reparametrization","interdisciplinary","characterisations","contextualization","spectroradiometer","probabilistically","neuropsychological","nonparametrically","interdependencies","conceptualization","misclassifications","indistinguishable","conceptualizations","featurescomponents","parameterizations","parallelizability","straightforwardly","electroencephalography","interchangeability","regressionclassification","neurodegenerative","telecommunications","electrophysiology","detectionrecognition"],"y":[1.0,1.0,0.5,0.6666666666666667,0.0,0.11111111111111112,0.0,1.0,0.4,0.5,0.4,0.625,0.5,0.5,0.25,0.33333333333333337,1.0,0.5,0.0,0.7142857142857143],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	acceptancerejection
# 	explodingvanishing
# 	spectroradiometer
# 	straightforwardly
# 	electroencephalography
# 	regressionclassification
# Some words which never appear in Statistics papers:
# 	telecommunication
# 	multilayerperception
# 	neurophysiological
# 	characterisations
# 	neuropsychological
# 	conceptualization
# 	conceptualizations
# 	featurescomponents
# 	interchangeability
# 	telecommunications
# 	detectionrecognition

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.3649639948852546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.3753993610223642
